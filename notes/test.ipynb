# %%
import requests
import json

# Replace with your actual OpenRouter API key
api_key = "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"

# Chat message payload
payload = {
    "model": "openai/gpt-oss-20b:free",
    "messages": [
        {"role": "user", "content": "Hello! What's the meaning of life?"}
    ]
}

# Headers for the request
headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

# Send POST request to OpenRouter
response = requests.post(
    url="https://openrouter.ai/api/v1/chat/completions",
    headers=headers,
    data=json.dumps(payload)
)

# Parse and print the chatbot response
if response.status_code == 200:
    reply = response.json()["choices"][0]["message"]["content"]
    print("Bot reply:", reply)
else:
    print("Error:", response.status_code, response.text)
# Out:
# Bot reply: Hey there! That's one of life’s biggest—and most personal—questions. There isn’t a single answer that fits everyone, but here are a few frames that might help you think about it:
#
# | Perspective | What it says the *meaning* might be | How it can feel in everyday life |
# |-------------|-----------------------------------|----------------------------------|
# | **Scientific/Existential** | Life has no pre‑written purpose; we create one by choosing goals, relationships, and values. | Each decision feels like a chance to write a new chapter. |
# | **Religious / Spiritual** | Often tied to a higher power, moral code, or cosmic order. | Knowing a bigger plan can bring comfort and guidance. |
# | **Humanist / Secular Ethics** | Meaning comes from improving ourselves and others, cultivating empathy, and contributing to humanity. | Seeing progress in your community can be incredibly fulfilling. |
# | **Narrative / Personal Story** | Your story is built from moments of growth, struggle, and connection. | Reflecting on your journey can reveal unexpected purpose. |
# | **Stoic / Impermanence** | Focus on what you control, accept what you can’t. Meaning is living virtuously in the present. | Staying present can reduce anxiety and increase joy. |
#
# ### A quick exercise
# 1. **Identify a passion**: What makes you feel alive? Music? Writing? Help others?
# 2. **Spot your impact**: How does that passion touch others or the world?
# 3. **Set a tiny goal**: Pick one small, concrete action you can do today that aligns with that passion and impact.
#
# Doing that each day gradually builds a life that feels meaningful, even if the ultimate “big why” remains a personal mystery. Whatever you find, remember that the journey itself often carries its own purpose. 🚀
